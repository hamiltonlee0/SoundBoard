# %% [markdown]
# Testing Audio recorded from Teensy Board

# %%
import numpy as np
import IPython.display as ipd
val = np.loadtxt("AudioTest.txt", comments = "#", delimiter = ", ", unpack = False)
print(val)
# Out:
# [[0.00000e+00 6.53130e+04]
#  [1.00000e+00 6.53140e+04]
#  [2.00000e+00 6.53120e+04]
#  ...
#  [1.76397e+05 6.39840e+04]
#  [1.76398e+05 6.39290e+04]
#  [1.76399e+05 6.38620e+04]]

# %%
samples = np.zeros(len(val))
for i in range(len(val)):
    samples[i] = val[i][1]
print(np.max(np.abs(samples)))
ipd.Audio(samples, rate = 44100)
# Out:
# 65330.0
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
